# %%
from weasyprint import HTML, CSS
# Out:
# /home/sangram/Encfs/prodigal_encrypted/venv/lib/python3.6/site-packages/weasyprint/document.py:36: UserWarning: There are known rendering problems and missing features with cairo < 1.15.4. WeasyPrint may work with older versions, but please read the note about the needed cairo version on the "Install" page of the documentation before reporting bugs. http://weasyprint.readthedocs.io/en/latest/install.html
#   'There are known rendering problems and missing features with '

# %%
srcf = '/home/sangram/Encfs/prodigal_encrypted/slack_downloads/output - filled.html'
src_css = '/home/sangram/Encfs/prodigal_encrypted/export_pdf_try.css'
dstf = '/home/sangram/Encfs/prodigal_encrypted/scorecard_filled.pdf'

# %%
html = HTML(srcf)
css = CSS(src_css)
html.write_pdf(dstf)#, stylesheets=[css])
# Out:
# ---------------------------------------------------------------------------
# CairoError                                Traceback (most recent call last)
# ~/Encfs/prodigal_encrypted/venv/lib/python3.6/site-packages/weasyprint/draw.py in stacked(context)
#      87     try:
# ---> 88         yield
#      89     finally:
#
# ~/Encfs/prodigal_encrypted/venv/lib/python3.6/site-packages/weasyprint/draw.py in draw_stacking_context(context, stacking_context, enable_hinting)
#     266             for child_context in stacking_context.zero_z_contexts:
# --> 267                 draw_stacking_context(context, child_context, enable_hinting)
#     268
#
# ~/Encfs/prodigal_encrypted/venv/lib/python3.6/site-packages/weasyprint/draw.py in draw_stacking_context(context, stacking_context, enable_hinting)
#     277             context.pop_group_to_source()
# --> 278             context.paint_with_alpha(box.style['opacity'])
#     279
#
# ...

# %%
import pdfkit

# %%
pdfkit.from_file(srcf, dstf)
# Out:
# Loading page (1/2)
# Printing pages (2/2)
# Done
# True
